# %% [markdown]
# $$n=18; i=15$$
#
# **Задача 1.** Пусть $\xi \sim B(1,\theta)$ - биномиальная случайная величина с вероятностью успеха в одном опыте - $\theta$. Возможные значения параметра $\theta_1=0,3+(\frac{i}{10n})$, $\theta_2=0,5+(\frac{i}{10n}) $. Множество решений состоит из двух элементов $D=\{d_1, d_2 \}$. Функция потерь $L$ имеет вид
#
# |          | $d_1$ | $d_2$ |
# |:--------:|:-----:|:-----:|
# |$\theta_1$| $0$   | $2+(\frac{i}{n})$   |
# |$\theta_2$|  $3+(\frac{1,5 \cdot i}{n})$  | $1+(\frac{0,5 \cdot i}{n})$   |
#
# **Найти:**
# ---
# **а.**  Оптимальную минимаксную решающую  $\delta^*(x)$
#
# $\xi \sim B(1,\theta)$
#
# $X = \{0, 1\}$ - множество возможных исходов
#
# $\theta_1=0,3+(\frac{15}{10 \cdot 18})= \frac{23}{60}$
#
# $\theta_2=0,5+(\frac{15}{10 \cdot 18}) = \frac{7}{12}$
#
# Функция потерь $L$ имеет вид
#
# |          | $d_1$ | $d_2$ |
# |:--------:|:-----:|:-----:|
# |$\theta_1$| $0$   | $2 + \frac{15}{18} = \frac{17}{6}$   |
# |$\theta_2$|  $3+\frac{1,5 \cdot 15}{18} = \frac{17}{4}$  | $1 + \frac{0,5 \cdot 15}{18} = \frac{17}{12}$   |
#
# Возможные решающие функции
#
# $\delta_1 = d_1, x=\{0, 1\} $
#
# $\delta_2 = d_2, x=\{0, 1\} $
#
# $\delta_3 = \{d_1, x=0;\quad d_2, x=1 \}$
#
# $\delta_4 = \{d_1, x=1;\quad d_2, x=0 \}$
#
# Функция риска
#
# $R(\theta_i, \delta_j) = ML\big(\theta_i, \delta_j(\xi)\big) = P(\xi=0 | \theta_i) \cdot L\big(\theta_i, \delta_j(0)\big) \quad + \quad P(\xi=1 | \theta_i) \cdot L\big(\theta_i, \delta_j(1)\big)$
#
# Рассчитаем функции риска для каждой $\delta_j$ с возможными $\theta_i$
#
# $R(\theta_1, \delta_1) = ML(\theta_1, \delta_1) =  \frac{23}{60} \cdot L(\theta_1, \delta_1(1)) + \frac{37}{60} \cdot L(\theta_1, \delta_1(0)) = \frac{23}{60} \cdot 0 + \frac{37}{60} \cdot 0 = 0$
#
# $R(\theta_2, \delta_1) = ML(\theta_2, \delta_1) =  \frac{7}{12} \cdot L(\theta_2, \delta_1(1)) + \frac{5}{12} \cdot L(\theta_2, \delta_1(0)) = \frac{7}{12} \cdot \frac{17}{4} + \frac{5}{12} \cdot \frac{17}{4} = \frac{17}{4} = 4.25$
#
# $R(\theta_1, \delta_2) = ML(\theta_1, \delta_2) =  \frac{23}{60} \cdot L(\theta_1, \delta_2(1)) + \frac{37}{60} \cdot L(\theta_1, \delta_2(0)) = \frac{23}{60} \cdot \frac{17}{6} + \frac{37}{60} \cdot \frac{17}{6} \approx 2.83$
#
# $R(\theta_2, \delta_2) = ML(\theta_2, \delta_2) =  \frac{7}{12} \cdot L(\theta_2, \delta_2(1)) + \frac{5}{12} \cdot L(\theta_2, \delta_2(0)) = \frac{7}{12} \cdot \frac{17}{12} + \frac{5}{12} \cdot \frac{17}{12} = \frac{17}{12} \approx 1.417$
#
# $R(\theta_1, \delta_3) = ML(\theta_1, \delta_3) =  \frac{23}{60} \cdot L(\theta_1, \delta_3(1)) + \frac{37}{60} \cdot L(\theta_1, \delta_3(0)) = \frac{23}{60} \cdot \frac{17}{6} + \frac{37}{60} \cdot 0 \approx 1.0861$
#
# $R(\theta_2, \delta_3) = ML(\theta_2, \delta_3) =  \frac{7}{12} \cdot L(\theta_2, \delta_3(1)) + \frac{5}{12} \cdot L(\theta_2, \delta_3(0)) = \frac{7}{12} \cdot \frac{17}{12} + \frac{5}{12} \cdot \frac{17}{4} \approx 2.597$
#
# $R(\theta_1, \delta_4) = ML(\theta_1, \delta_4) =  \frac{23}{60} \cdot L(\theta_1, \delta_4(1)) + \frac{37}{60} \cdot L(\theta_1, \delta_4(0)) = \frac{23}{60} \cdot 0 + \frac{37}{60} \cdot \frac{17}{6} \approx 1.747$
#
# $R(\theta_2, \delta_4) = ML(\theta_2, \delta_4) =  \frac{7}{12} \cdot L(\theta_2, \delta_4(1)) + \frac{5}{12} \cdot L(\theta_2, \delta_4(0)) = \frac{7}{12} \cdot \frac{17}{4} + \frac{5}{12} \cdot \frac{17}{12} \approx 3.069$
#
# Найдем максимальное значение функции потерь для каждой $\delta_j$
#
# $R(\theta_i, \delta_1) = 4.25$
#
# $R(\theta_i, \delta_2) = 2.83$
#
# $R(\theta_i, \delta_3) = 2.597$
#
# $R(\theta_i, \delta_4) = 3.069$
#
# По принципу минимакса $\delta_3$ - оптимальная минимаксная решающая функция
#
# *Ответ:* $\delta^*(x) = \delta_3$
#
# ---
#
# **б.** Пусть имеет априорное распределение $\pi(\theta_1) = \beta, \pi(\theta_2) = (1 - \beta), \quad 0< \beta < 1 $. Найти оптимальное байесовское решение $\delta^*(x)$ и байесовский риск $r(\delta^*)$.  Построить график в зависимости от $\beta$.
#
# Найдем полные вероятности появления возможных $\xi$
#
# $P(\xi=0) = \pi(\theta_1) \cdot P(\xi=0| \theta_1) + \pi(\theta_2) \cdot P(\xi=0| \theta_2) = \beta \cdot (1-\theta_1) +  (1-\beta) \cdot (1-\theta_2) = \\
# = \frac{37}{60}\beta + \frac{5}{12} - \frac{5}{12}\beta =  \frac{5}{12}  + \frac{1}{5}\beta$
#
# $P(\xi=1) = 1 - P(\xi=0) = 1 - ( \frac{5}{12} + \frac{1}{5}\beta )=  \frac{7}{12} - \frac{1}{5}\beta$
#
# Вычислим условные вероятности параметра $\theta$ при $\xi=x; x = \{0, 1\}$
#
# $P(\theta=\theta_1|\xi=1) = \frac{\pi(\theta_1)P(\xi=1|\theta_1)}{P(\xi=1)} = \frac{\frac{23}{60}\beta}{\frac{7}{12} - \frac{1}{5}\beta} = \frac{23\beta}{35-12\beta}$
#
# $ P(\theta=\theta_2|\xi=1) = 1 - P(\theta=\theta_1|\xi=1) = 1 -  \frac{23\beta}{35-12\beta} = \frac{35(1- \beta)}{35-12\beta}$
#
# $P(\theta=\theta_1|\xi=0) = \frac{\pi(\theta_1)P(\xi=0|\theta_1)}{P(\xi=0)} = \frac{\frac{37}{60}\beta}{\frac{5}{12}  + \frac{1}{5}\beta} = \frac{37\beta}{25+12\beta}$
#
# $P(\theta=\theta_2|\xi=0) = 1 - P(\theta=\theta_1|\xi=0) = 1 - \frac{37\beta}{25+12\beta} = \frac{25(1- \beta)}{25+12\beta}$
#
# Найдем оптимальное решение.
#
# Срение потери по условыным распределения $\beta$
#
# $ML(\theta | \xi=0, d=d_1) = P(\theta_1| \xi=0)L(\theta_1, d_1) + P(\theta_2| \xi=0)L(\theta_2, d_1) = \frac{37\beta}{25+12\beta} \cdot 0 +\\
# +\frac{25(1- \beta)}{25+12\beta} \cdot \frac{17}{4} = \frac{425(1-\beta)}{100+48\beta}$
#
# $ML(\theta | \xi=0, d=d_2) = P(\theta_1| \xi=0)L(\theta_1, d_2) + P(\theta_2| \xi=0)L(\theta_2, d_2) = \frac{37\beta}{25+12\beta} \cdot \frac{17}{6} +\\
# +\frac{25(1- \beta)}{25+12\beta} \cdot \frac{17}{12} = \frac{833\beta+425}{300+144\beta}$
#
# $ML(\theta | \xi=1, d=d_1) = P(\theta_1| \xi=1)L(\theta_1, d_1) + P(\theta_2| \xi=1)L(\theta_2, d_1) = \frac{23\beta}{35-12\beta} \cdot 0 +\\
# +\frac{35(1- \beta)}{35-12\beta} \cdot \frac{17}{4} = \frac{595(1-\beta)}{140-48\beta}$
#
# $ML(\theta | \xi=1, d=d_2) = P(\theta_1| \xi=1)L(\theta_1, d_2) + P(\theta_2| \xi=1)L(\theta_2, d_2) = \frac{23\beta}{35-12\beta} \cdot \frac{17}{6} +\\
# +\frac{35(1- \beta)}{35-12\beta} \cdot \frac{17}{12} = \frac{187\beta + 595}{420 - 144\beta}$

# %%
import numpy as np
import matplotlib.pyplot as plt
b = np.linspace(0, 1, 200)
d1 = (425 * (1 - b)) / (100 + 48* b)
d2 = (833 * b + 425) / (300 + 144 * b)
plt.figure(figsize=(4, 3))
plt.plot(b, d1, label="$ML(\\theta | \\xi=0, d=d_1)$")
plt.plot(b, d2, label="$ML(\\theta | \\xi=0, d=d_2)$")
plt.legend(loc='upper right')
plt.xlabel('$\\beta$')
plt.ylabel('$ML$')
plt.title('Графики $ML$ в зависимости от $\\beta$')
plt.grid(True)
plt.show()

# %% [markdown]
# Найдем точку пересечения: $\frac{425(1-\beta)}{100+48\beta} = \frac{833\beta+425}{300+144\beta}$; $\beta = \frac{25}{62} \approx 0.4$

# %%
import numpy as np
import matplotlib.pyplot as plt
b = np.linspace(0, 1, 200)
d1 = (595 * (1 - b)) / (140 - 48* b)
d2 = (187 * b + 595) / (420 - 144 * b)
plt.figure(figsize=(4, 3))
plt.plot(b, d1, label="$ML(\\theta | \\xi=1, d=d_1)$")
plt.plot(b, d2, label="$ML(\\theta | \\xi=1, d=d_2)$")
plt.legend(loc='upper right')
plt.xlabel('$\\beta$')
plt.ylabel('$ML$')
plt.title('Графики $ML$ в зависимости от $\\beta$')
plt.grid(True)
plt.show()

# %% [markdown]
# Найдем точку пересечения: $\frac{595(1-\beta)}{140-48\beta} = \frac{187\beta + 595}{420 - 144\beta}$; $\beta = \frac{35}{58} \approx 0.6$
#
# Оптимальное баесовское решение:
# $$\delta_*(x) = \begin{cases}
# \beta \in (0, \frac{25}{62}]: d_2, x= 0, 1\\
# \beta \in (\frac{25}{62}, \frac{35}{58}]: d_1, x= 0;\quad d_2, x=1\\
# \beta \in (\frac{35}{58}, 1): d_2, x = 0, 1
# \end{cases}$$
#
# **Задача 2.** Пусть $\xi \sim G(\theta)$ - геометрическая случайная величина с вероятностью успеха в одном опыте - $\theta$.  Смысл - $\xi$ количество опытов до первого успеха. Возможные значения параметра $\theta_1=0,3+(\frac{i}{10n})$, $\theta_2=0,5+(\frac{i}{10n}) $. Функция потерь $L$ имеет вид
#
# |          | $d_1$ | $d_2$ |
# |:--------:|:-----:|:-----:|
# |$\theta_1$| $0$   | $4+(\frac{i}{n})$   |
# |$\theta_2$|  $1+(\frac{i}{n})$  | $0$   |
#
# Определить минимаксную решающую функцию среди функций:
# $$\delta_i(x) = \begin{cases}
# d_1, x=1,2,...,i \\
# d_2, x=i+1,i+2,... \\
# \end{cases}$$
#
#
# $X=\{1, 2, 3...\}$ – множество возможных исходов
#
# $\theta_1=0,3+\frac{15}{10\cdot18} =  \frac{23}{60}; \quad \theta_2=0,6+\frac{15}{10\cdot18} =  \frac{41}{60}$
#
# Функция потерь $L$ имеет вид
#
# |          | $d_1$ | $d_2$ |
# |:--------:|:-----:|:-----:|
# |$\theta_1$| $0$   | $\frac{29}{6}$   |
# |$\theta_2$|  $\frac{11}{6}$  | $0$   |
#
# Функции риска:
#
# $R(\theta_1, \delta_i) = ML(\theta_1, \delta_i) = P(\xi \leq i, \theta_1) \cdot L(\theta_1, d_1) + P(\xi \gt i, \theta_1) \cdot L(\theta_1, d_2) =\\
# =(1 - (1-\theta_1)^i) \cdot 0 + (1-\theta_1)^i \cdot \frac{29}{6} =  \frac{29}{6}(1-\theta_1)^i =  \frac{29}{6}(1- \frac{23}{60})^i = \frac{29}{6}(\frac{37}{60})^i$
#
# $R(\theta_2, \delta_i) = ML(\theta_2, \delta_i) = P(\xi \leq i, \theta_2) \cdot L(\theta_2, d_1) + P(\xi \gt i, \theta_2) \cdot L(\theta_2, d_2) =\\
# =(1 - (1-\theta_2)^i) \cdot \frac{11}{6} + (1-\theta_2)^i \cdot 0 =  \frac{11}{6}(1 - (1-\theta_2)^i) =  \frac{11}{6}(1 - (\frac{19}{60})^i)$
#
# Для каждой решающей функции найдем максимум потерь
#
# |     $i$     | $1$ | $2$ | $3$ | $4$ |$...$|
# |--------|:-----:|:-----:|:-----:|:-----:|:-----:|
# |$$\frac{29}{6}(\frac{37}{60})^i$$| $2.98$   | $1.838$   | $1.1334 $| $0.6989$| |
# |$$\frac{11}{6}(1 - (\frac{19}{60})^i)$$|  $0.7027$  | $1.1361$   | $1.4034 $| $1.5682$ | |
# |**max** |  $2.98$  | $1.838 $   | $1.4034$| $1.5682$ | |
#
#
#
# **Ответ:** минимаксная решающая функция - $\delta_3$
#
# **Задача 3.** Пусть $\xi \sim \Pi(\theta)$ - пуассоновская случайна величина с параментром $\theta$.  Множество значанией с.в $\xi$  - $X = \{0,1,2,3,...\}$. Возможные значения параметра $\theta_1=1,3+2(\frac{i}{n})$, $\theta_2=2+(\frac{i}{n}) $. Функция потерь аналогична функии потерь из задачи 2.
#
# Определить минимаксную решающую функцию среди функций:
# $$\delta_i(x) = \begin{cases}
# d_1, x=0,1,2,...,i \\
# d_2, x=i+1,i+2,... \\
# \end{cases}$$
#
# $ \theta_1=1,3+2(\frac{15}{18}) \approx 2.967; \quad \theta_2=2+(\frac{15}{18}) \approx 2.833$
#
# Функции риска:
#
# $R(\theta_1, \delta_i) = ML(\theta_1, \delta_i) = P(\xi \leq i, \theta_1) \cdot L(\theta_1, d_1) + P(\xi \gt i, \theta_1) \cdot L(\theta_1, d_2) = F_{\Pi(\theta_1)}(i) \cdot 0 +\\+ (1-F_{\Pi(\theta_1)}(i)) \cdot \frac{29}{6} = \frac{29}{6} (1-F_{\Pi(\theta_1)}(i))$
#
# $R(\theta_2, \delta_i) = ML(\theta_2, \delta_i) = P(\xi \leq i, \theta_2) \cdot L(\theta_2, d_1) + P(\xi \gt i, \theta_2) \cdot L(\theta_2, d_2) = F_{\Pi(\theta_2)}(i) \cdot \frac{11}{6} +\\+ (1-F_{\Pi(\theta_2)}(i)) \cdot 0 = \frac{11}{6} F_{\Pi(\theta_2)}(i)$
#
#
# Для каждой решающей функции найдем максимум потерь
#
# |     $i$     | $0$ | $1$ | $2$ | $3$ |$4$| $5$| ... |
# |:--------:|:-----:|:-----:|:-----:|:-----:|:-----:|:-----:|:-----:|
# |$$\frac{29}{6}(1-F_{\Pi(\theta_1)}(i))$$| $4.584$   | $3.846 $   | $ 2.751 $| $ 1.669$| $ 0.8662 $|$0.3896$ | |
# |$$\frac{11}{6}F_{\Pi(\theta_2)}(i)$$|  $0.1078$  | $0.4134 $   | $0.8463 $| $ 1.2550 $ | $ 1.544$ | $ 1.708$| |
# |max|  $4.584$  | $3.846$   | $2.751 $| $1.669$ | $1.544$ | $1.708$| |
#
# **Ответ:** минимаксная решающая функция - $\delta_4$
#
# **Задача 4.** Классификация наблюдений
#
# 1. Смоделировать 6 переменных RndNorm (1) размерностью 30 – var1, var2, …, var6.

# %%
import numpy as np
import pandas as pd
np.random.seed(0)
N=30
var1 = np.random.randn(N)
var2 = np.random.randn(N)
var3 = np.random.randn(N)
var4 = np.random.randn(N)
var5 = np.random.randn(N)
var6 = np.random.randn(N)
n = 18
i = 15
df = pd.DataFrame({'var1': var1,'var2': var2,'var3': var3,'var4': var4,'var5': var5,'var6': var6}) 
df['x1'] = (n / (2 * i)) * df['var1'] + (n / i) * df['var2'] - (n / (2 * i)) * df['var3'] + n
df['x2'] = (3 * n / (2 * i)) * df['var1'] - (n / i) * df['var2'] + (n / (3 * i)) * df['var3'] + 1.5 * n
df['x3'] = (n / (2 * i)) * df['var1'] + (n / (3 * i)) * df['var2'] - (n / i) * df['var3'] + n / 2
df['y1'] = ((n + 1) / (2 * i)) * df['var4'] + (n / i) * df['var5'] - (n / (2 * i)) * df['var6'] + n + 5
df['y2'] = (3 * n / (2 * i)) * df['var4'] - ((n + 1) / i) * df['var5'] + (n / (3 * i)) * df['var6'] + 1.5 * n + 4
df['y3'] = (n / (2 * i)) * df['var4'] + (n / (3 * i)) * df['var5'] - ((n + 1) / i) * df['var6'] + (2 * n / 3)
df = df.drop(columns=['var1', 'var2', 'var3', 'var4', 'var5', 'var6'])
print(df)
# Out:
#            x1         x2         x3         y1         y2         y3
# 0   19.647845  29.720373  10.927363  23.237310  29.770179  11.995103
# 1   18.909621  27.122667   9.822823  21.426929  35.278313  10.123473
# 2   18.009788  29.501813  10.207904  23.936646  30.699225  13.187616
# 3   18.003350  32.720050  11.623756  25.706064  30.747286  14.163360
# 4   18.596585  30.850069   9.768459  22.451289  32.481864  12.060699
# 5   17.842321  24.892569   8.958310  23.666022  32.195977  13.204496
# 6   21.024521  26.581731  12.018407  21.808484  32.020749  10.405166
# 7   19.074372  25.469814   8.834799  26.998127  31.440194  15.179141
# 8   18.017656  26.916079   9.871896  24.575613  29.917881  13.798525
# 9   17.852429  28.122619   9.063104  24.006239  31.032335  12.958750
# 10  16.390708  28.809178   7.792096  23.567582  35.165685  13.452765
# 11  17.091153  31.373307   9.149777  21.635799  28.662798   8.962970
# 12  15.725458  30.873152   7.406834  20.816508  29.947050   9.765376
# ...

# %% [markdown]
# 2. Образовать 3 переменных $Z_1$, $Z_2$, $Z_3$ размерностью 60 – координаты объединенных выборок из двух совокупностей
# 3. Образовать группирующую переменную $G$ (первые 30 строк – 1, вторые 30 строк – 2).

# %%
x = df[['x1', 'x2', 'x3']].to_numpy()
y = df[['y1', 'y2', 'y3']].to_numpy()
m = x.mean(axis=0)
v = y.mean(axis=0)
s_1 = np.cov((x-m).T)
s_2 = np.cov((y-v).T)
D = (s_1 + s_2) / 2
D_inv = np.linalg.inv(D)
p_m = (m - v).T @ D_inv @ (m - v)
def classificate(x):
    return (m.T @ D_inv @ x - 0.5 * m.T @ D_inv @ m <= v.T @ D_inv @ x - 0.5 * v.T @ D_inv @ v) + 1

z = np.vstack([x, y])
Z1 = pd.concat([df['x1'], df['y1']], ignore_index=True)
Z2 = pd.concat([df['x2'], df['y2']], ignore_index=True)
Z3 = pd.concat([df['x3'], df['y3']], ignore_index=True)
G = np.concatenate([np.full(30, 1), np.full(30, 2)])
df_combined = pd.DataFrame({'z1': Z1, 'z2': Z2, 'z3': Z3, 'G': G, 'result': [classificate(xi) for xi in z]})
print(df_combined)
# Out:
#            z1         z2         z3  G  result
# 0   19.647845  29.720373  10.927363  1       1
# 1   18.909621  27.122667   9.822823  1       1
# 2   18.009788  29.501813  10.207904  1       1
# 3   18.003350  32.720050  11.623756  1       1
# 4   18.596585  30.850069   9.768459  1       1
# 5   17.842321  24.892569   8.958310  1       1
# 6   21.024521  26.581731  12.018407  1       1
# 7   19.074372  25.469814   8.834799  1       1
# 8   18.017656  26.916079   9.871896  1       1
# 9   17.852429  28.122619   9.063104  1       1
# 10  16.390708  28.809178   7.792096  1       1
# 11  17.091153  31.373307   9.149777  1       1
# 12  15.725458  30.873152   7.406834  1       1
# 13  21.154831  24.384154  11.335106  1       1
# 14  17.413330  28.571473   8.579647  1       1
# 15  18.085401  27.852379   9.846747  1       1
# 16  17.915571  30.844378  10.440286  1       1
# 17  19.157203  25.466187   9.882521  1       1
# 18  16.438095  29.375578   8.916145  1       1
# ...

# %%
from IPython.display import Latex
from printmd import  *
display(mdMatrix( "D", D))
display(mdLabelNumber("p_M^2", p_m))
a = vectorToStr(m.T @ D_inv - v.T @ D_inv)
b = "{:.2f}".format(-0.5 * m.T @ D_inv @ m + 0.5 * v.T @ D_inv @ v)
display(Latex("Функция классификации: $$(\overrightarrow{\mu}^T - \overrightarrow{\\nu}^T) \cdot D^{-1} \cdot \overrightarrow{z} - \\frac{1}{2} (\overrightarrow{\mu}^TD^{-1}\overrightarrow{\mu} - \overrightarrow{\\nu}^TD^{-1}\overrightarrow{\\nu}) =" + a + "\overrightarrow{z}-" + b + "$$"))
# Out:
# $$D= \begin{pmatrix}1.87 & -0.59 & 1.48 \\ -0.59 & 5.87 & 0.09 \\ 1.48 & 0.09 & 1.88\end{pmatrix}$$
# $$p_M^2=    25.6724$$
# Функция классификации: $$(\overrightarrow{\mu}^T - \overrightarrow{\nu}^T) \cdot D^{-1} \cdot \overrightarrow{z} - \frac{1}{2} (\overrightarrow{\mu}^TD^{-1}\overrightarrow{\mu} - \overrightarrow{\nu}^TD^{-1}\overrightarrow{\nu}) =\begin{pmatrix}-5.36 \\ -1.20 \\ 2.60\end{pmatrix}\overrightarrow{z}-118.85$$
